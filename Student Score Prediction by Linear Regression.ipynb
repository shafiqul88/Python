# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 2: Create dataset
data = {
    'Hours': [1, 2, 3, 4, 5, 6],
    'Score': [20, 40, 50, 65, 80, 90]
}

df = pd.DataFrame(data)
x = df[['Hours']]
y = df['Score']

# %%
#visualize Data
plt.scatter(x,y, color='blue')
plt.xlabel('Student Study Hours')
plt.ylabel('Student Score')
plt.title('Hours vs Score')
plt.show()

# %%
#Train the model
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
#check model accuracy
print("Model Coefficent(slope):", model.coef_[0])
print("Model Intercept: ", model.intercept_)
print("Model Accuracy: ", model.score(x,y))
# Out:
# Model Coefficent(slope): 13.857142857142858
# Model Intercept:  9.0
# Model Accuracy:  0.991987348444913

# %%
#make predictions
hours = np.array([[7.5]])
predicted_score = model.predict(hours)
print(predicted_score[0])
# Out:
# 112.92857142857143
# c:\Users\IT PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x,y, color='blue', label='Actual Data')
plt.plot(x, model.predict(x),color='red', label='Regression Line')
plt.xlabel("Student Study Hours")
plt.ylabel("Student Score")
plt.legend()
plt.show()

# %%
# Out:
# 0    20
# 1    40
# 2    50
# 3    65
# 4    80
# 5    90
# Name: Score, dtype: int64
